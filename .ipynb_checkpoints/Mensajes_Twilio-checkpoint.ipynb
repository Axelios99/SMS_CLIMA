# %%
#!pip3 install twilio

# %%
#Importamos sistema operativo, la api rest de twilio, la configuración hecha por nosotros para usar la api de twilio
#Tambien importamos json dado que lo necesitaremos
import os
from twilio.rest import Client
from twilio_config import TWILIO_ACCOUNT_SID, TWILIO_AUTH_TOKEN, PHONE_NUMBER, API_KEY_WAPI
import json
print(TWILIO_ACCOUNT_SID)
print(TWILIO_AUTH_TOKEN)
print(PHONE_NUMBER)
print(API_KEY_WAPI)
# Out:
# AC3a7eb4f5e96001b1139d3b6aba50b21f
# 84f88fe4910eb70e2ddf442bdc5f25d4
# +17432224721
# 40797fb78440446ea97162227231601

# %%
import time
#Importamos requests para usos del api
#Esta librería se encarga de obtener respuestas que se realizan en el protoloco HTTP de una plataforma web que se haya establecido con anterioridad con una API.
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects

# %%
#importamos pandas, importamos requests, beautifulSoup y tqdm
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm


from datetime import datetime

# %% [markdown]
# # ARMADO DE LA URL

# %%
query = 'Bogotá'
api_key = API_KEY_WAPI
url_clima = 'https://api.weatherapi.com/v1/forecast.json?key='+api_key+'&q='+query+'&days=1&aqi=no&alerts=no'

# %%
#Llamado al API para que nos responda y esa respuesta la convertimos en un JSON
response = requests.get(url_clima).json()

# %%
#Ver que me trajo la api
response
# Out:
# {'location': {'name': 'Bogotá',
#   'region': 'Cundinamarca',
#   'country': 'Kolumbien',
#   'lat': 4.6,
#   'lon': -74.08,
#   'tz_id': 'America/Bogota',
#   'localtime_epoch': 1673974426,
#   'localtime': '2023-01-17 11:53'},
#  'current': {'last_updated_epoch': 1673973900,
#   'last_updated': '2023-01-17 11:45',
#   'temp_c': 16.0,
#   'temp_f': 60.8,
#   'is_day': 0,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#    'code': 1003},
#   'wind_mph': 5.6,
#   'wind_kph': 9.0,
#   'wind_degree': 320,
#   'wind_dir': 'NW',
#   'pressure_mb': 1027.0,
#   'pressure_in': 30.33,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 72,
#   'cloud': 50,
#   'feelslike_c': 16.0,
#   'feelslike_f': 60.8,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.0,
#   'gust_mph': 2.9,
#   'gust_kph': 4.7},
#  'forecast': {'forecastday': [{'date': '2023-01-17',
#     'date_epoch': 1673913600,
#     'day': {'maxtemp_c': 17.6,
#      'maxtemp_f': 63.7,
#      'mintemp_c': 9.4,
#      'mintemp_f': 48.9,
#      'avgtemp_c': 12.3,
#      'avgtemp_f': 54.2,
#      'maxwind_mph': 2.5,
#      'maxwind_kph': 4.0,
#      'totalprecip_mm': 3.2,
#      'totalprecip_in': 0.13,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.8,
#      'avgvis_miles': 6.0,
#      'avghumidity': 85.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 85,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 3.0},
#     'astro': {'sunrise': '06:10 AM',
#      'sunset': '06:03 PM',
#      'moonrise': '01:42 AM',
#      'moonset': '01:54 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': '30'},
#     'hour': [{'time_epoch': 1673931600,
#       'time': '2023-01-17 00:00',
#       'temp_c': 9.9,
#       'temp_f': 49.8,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 131,
#       'wind_dir': 'SE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 94,
#       'cloud': 72,
#       'feelslike_c': 10.3,
#       'feelslike_f': 50.5,
#       'windchill_c': 10.3,
#       'windchill_f': 50.5,
#       'heatindex_c': 9.9,
#       'heatindex_f': 49.8,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 60,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.4,
#       'gust_kph': 5.4,
#       'uv': 1.0},
#      {'time_epoch': 1673935200,
#       'time': '2023-01-17 01:00',
#       'temp_c': 9.8,
#       'temp_f': 49.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 139,
#       'wind_dir': 'SE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 94,
#       'cloud': 56,
#       'feelslike_c': 9.8,
#       'feelslike_f': 49.6,
#       'windchill_c': 9.8,
#       'windchill_f': 49.6,
#       'heatindex_c': 9.8,
#       'heatindex_f': 49.6,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.9,
#       'gust_kph': 4.7,
#       'uv': 1.0},
#      {'time_epoch': 1673938800,
#       'time': '2023-01-17 02:00',
#       'temp_c': 9.4,
#       'temp_f': 48.9,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 118,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 93,
#       'cloud': 53,
#       'feelslike_c': 9.4,
#       'feelslike_f': 48.9,
#       'windchill_c': 9.4,
#       'windchill_f': 48.9,
#       'heatindex_c': 9.4,
#       'heatindex_f': 48.9,
#       'dewpoint_c': 8.3,
#       'dewpoint_f': 46.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.9,
#       'gust_kph': 4.7,
#       'uv': 1.0},
#      {'time_epoch': 1673942400,
#       'time': '2023-01-17 03:00',
#       'temp_c': 9.6,
#       'temp_f': 49.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 116,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 93,
#       'cloud': 48,
#       'feelslike_c': 10.0,
#       'feelslike_f': 50.0,
#       'windchill_c': 10.0,
#       'windchill_f': 50.0,
#       'heatindex_c': 9.6,
#       'heatindex_f': 49.3,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 1.0},
#      {'time_epoch': 1673946000,
#       'time': '2023-01-17 04:00',
#       'temp_c': 9.9,
#       'temp_f': 49.8,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 114,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 92,
#       'cloud': 77,
#       'feelslike_c': 10.3,
#       'feelslike_f': 50.5,
#       'windchill_c': 10.3,
#       'windchill_f': 50.5,
#       'heatindex_c': 9.9,
#       'heatindex_f': 49.8,
#       'dewpoint_c': 8.6,
#       'dewpoint_f': 47.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 81,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.9,
#       'gust_kph': 4.7,
#       'uv': 1.0},
#      {'time_epoch': 1673949600,
#       'time': '2023-01-17 05:00',
#       'temp_c': 9.9,
#       'temp_f': 49.8,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 118,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 91,
#       'cloud': 32,
#       'feelslike_c': 10.3,
#       'feelslike_f': 50.5,
#       'windchill_c': 10.3,
#       'windchill_f': 50.5,
#       'heatindex_c': 9.9,
#       'heatindex_f': 49.8,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.9,
#       'gust_kph': 4.7,
#       'uv': 1.0},
#      {'time_epoch': 1673953200,
#       'time': '2023-01-17 06:00',
#       'temp_c': 9.8,
#       'temp_f': 49.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 118,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 90,
#       'cloud': 61,
#       'feelslike_c': 10.0,
#       'feelslike_f': 50.0,
#       'windchill_c': 10.0,
#       'windchill_f': 50.0,
#       'heatindex_c': 9.8,
#       'heatindex_f': 49.6,
#       'dewpoint_c': 8.3,
#       'dewpoint_f': 46.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.4,
#       'gust_kph': 5.4,
#       'uv': 1.0},
#      {'time_epoch': 1673956800,
#       'time': '2023-01-17 07:00',
#       'temp_c': 10.4,
#       'temp_f': 50.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 1.8,
#       'wind_kph': 2.9,
#       'wind_degree': 122,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 49,
#       'feelslike_c': 10.4,
#       'feelslike_f': 50.7,
#       'windchill_c': 10.4,
#       'windchill_f': 50.7,
#       'heatindex_c': 10.4,
#       'heatindex_f': 50.7,
#       'dewpoint_c': 8.5,
#       'dewpoint_f': 47.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.5,
#       'gust_kph': 4.0,
#       'uv': 4.0},
#      {'time_epoch': 1673960400,
#       'time': '2023-01-17 08:00',
#       'temp_c': 11.5,
#       'temp_f': 52.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 119,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 51,
#       'feelslike_c': 12.1,
#       'feelslike_f': 53.8,
#       'windchill_c': 12.1,
#       'windchill_f': 53.8,
#       'heatindex_c': 11.5,
#       'heatindex_f': 52.7,
#       'dewpoint_c': 8.9,
#       'dewpoint_f': 48.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.2,
#       'gust_kph': 3.6,
#       'uv': 4.0},
#      {'time_epoch': 1673964000,
#       'time': '2023-01-17 09:00',
#       'temp_c': 12.9,
#       'temp_f': 55.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 127,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 35,
#       'feelslike_c': 12.9,
#       'feelslike_f': 55.2,
#       'windchill_c': 12.9,
#       'windchill_f': 55.2,
#       'heatindex_c': 12.9,
#       'heatindex_f': 55.2,
#       'dewpoint_c': 9.1,
#       'dewpoint_f': 48.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.8,
#       'gust_kph': 2.9,
#       'uv': 4.0},
#      {'time_epoch': 1673967600,
#       'time': '2023-01-17 10:00',
#       'temp_c': 14.4,
#       'temp_f': 57.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 1.3,
#       'wind_kph': 2.2,
#       'wind_degree': 145,
#       'wind_dir': 'SE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 74,
#       'feelslike_c': 14.4,
#       'feelslike_f': 57.9,
#       'windchill_c': 14.4,
#       'windchill_f': 57.9,
#       'heatindex_c': 14.4,
#       'heatindex_f': 57.9,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 67,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.6,
#       'gust_kph': 2.5,
#       'uv': 3.0},
#      {'time_epoch': 1673971200,
#       'time': '2023-01-17 11:00',
#       'temp_c': 16.9,
#       'temp_f': 62.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 1.3,
#       'wind_kph': 2.2,
#       'wind_degree': 170,
#       'wind_dir': 'S',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 19,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.4,
#       'windchill_c': 16.9,
#       'windchill_f': 62.4,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.4,
#       'dewpoint_c': 10.0,
#       'dewpoint_f': 50.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.6,
#       'gust_kph': 2.5,
#       'uv': 5.0},
#      {'time_epoch': 1673974800,
#       'time': '2023-01-17 12:00',
#       'temp_c': 17.6,
#       'temp_f': 63.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 1.3,
#       'wind_kph': 2.2,
#       'wind_degree': 166,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 76,
#       'feelslike_c': 17.6,
#       'feelslike_f': 63.7,
#       'windchill_c': 17.6,
#       'windchill_f': 63.7,
#       'heatindex_c': 17.6,
#       'heatindex_f': 63.7,
#       'dewpoint_c': 10.4,
#       'dewpoint_f': 50.7,
#       'will_it_rain': 1,
#       'chance_of_rain': 74,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.6,
#       'gust_kph': 2.5,
#       'uv': 4.0},
#      {'time_epoch': 1673978400,
#       'time': '2023-01-17 13:00',
#       'temp_c': 17.3,
#       'temp_f': 63.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 1.3,
#       'wind_kph': 2.2,
#       'wind_degree': 147,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 66,
#       'cloud': 16,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 17.3,
#       'windchill_f': 63.1,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.1,
#       'dewpoint_c': 10.9,
#       'dewpoint_f': 51.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.6,
#       'gust_kph': 2.5,
#       'uv': 5.0},
#      {'time_epoch': 1673982000,
#       'time': '2023-01-17 14:00',
#       'temp_c': 15.7,
#       'temp_f': 60.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 146,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 74,
#       'cloud': 84,
#       'feelslike_c': 15.7,
#       'feelslike_f': 60.3,
#       'windchill_c': 15.7,
#       'windchill_f': 60.3,
#       'heatindex_c': 15.7,
#       'heatindex_f': 60.3,
#       'dewpoint_c': 11.1,
#       'dewpoint_f': 52.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 61,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 1.8,
#       'gust_kph': 2.9,
#       'uv': 4.0},
#      {'time_epoch': 1673985600,
#       'time': '2023-01-17 15:00',
#       'temp_c': 14.4,
#       'temp_f': 57.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 171,
#       'wind_dir': 'S',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 50,
#       'feelslike_c': 14.4,
#       'feelslike_f': 57.9,
#       'windchill_c': 14.4,
#       'windchill_f': 57.9,
#       'heatindex_c': 14.4,
#       'heatindex_f': 57.9,
#       'dewpoint_c': 11.3,
#       'dewpoint_f': 52.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.8,
#       'gust_kph': 2.9,
#       'uv': 4.0},
#      {'time_epoch': 1673989200,
#       'time': '2023-01-17 16:00',
#       'temp_c': 14.5,
#       'temp_f': 58.1,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 170,
#       'wind_dir': 'S',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.89,
#       'precip_mm': 1.1,
#       'precip_in': 0.04,
#       'humidity': 82,
#       'cloud': 69,
#       'feelslike_c': 14.5,
#       'feelslike_f': 58.1,
#       'windchill_c': 14.5,
#       'windchill_f': 58.1,
#       'heatindex_c': 14.5,
#       'heatindex_f': 58.1,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 64,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.0,
#       'gust_kph': 3.2,
#       'uv': 3.0},
#      {'time_epoch': 1673992800,
#       'time': '2023-01-17 17:00',
#       'temp_c': 14.1,
#       'temp_f': 57.4,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 1.3,
#       'wind_kph': 2.2,
#       'wind_degree': 168,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 69,
#       'feelslike_c': 14.1,
#       'feelslike_f': 57.4,
#       'windchill_c': 14.1,
#       'windchill_f': 57.4,
#       'heatindex_c': 14.1,
#       'heatindex_f': 57.4,
#       'dewpoint_c': 11.3,
#       'dewpoint_f': 52.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.6,
#       'gust_kph': 2.5,
#       'uv': 3.0},
#      {'time_epoch': 1673996400,
#       'time': '2023-01-17 18:00',
#       'temp_c': 12.5,
#       'temp_f': 54.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 1.1,
#       'wind_kph': 1.8,
#       'wind_degree': 158,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.3,
#       'precip_in': 0.01,
#       'humidity': 90,
#       'cloud': 82,
#       'feelslike_c': 12.5,
#       'feelslike_f': 54.5,
#       'windchill_c': 12.5,
#       'windchill_f': 54.5,
#       'heatindex_c': 12.5,
#       'heatindex_f': 54.5,
#       'dewpoint_c': 10.9,
#       'dewpoint_f': 51.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 65,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 1.6,
#       'gust_kph': 2.5,
#       'uv': 3.0},
#      {'time_epoch': 1674000000,
#       'time': '2023-01-17 19:00',
#       'temp_c': 12.2,
#       'temp_f': 54.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 1.6,
#       'wind_kph': 2.5,
#       'wind_degree': 163,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 91,
#       'cloud': 34,
#       'feelslike_c': 12.2,
#       'feelslike_f': 54.0,
#       'windchill_c': 12.2,
#       'windchill_f': 54.0,
#       'heatindex_c': 12.2,
#       'heatindex_f': 54.0,
#       'dewpoint_c': 10.8,
#       'dewpoint_f': 51.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 1.8,
#       'gust_kph': 2.9,
#       'uv': 1.0},
#      {'time_epoch': 1674003600,
#       'time': '2023-01-17 20:00',
#       'temp_c': 10.7,
#       'temp_f': 51.3,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 134,
#       'wind_dir': 'SE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 93,
#       'cloud': 86,
#       'feelslike_c': 10.9,
#       'feelslike_f': 51.6,
#       'windchill_c': 10.9,
#       'windchill_f': 51.6,
#       'heatindex_c': 10.7,
#       'heatindex_f': 51.3,
#       'dewpoint_c': 9.5,
#       'dewpoint_f': 49.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 1.0},
#      {'time_epoch': 1674007200,
#       'time': '2023-01-17 21:00',
#       'temp_c': 10.7,
#       'temp_f': 51.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.2,
#       'wind_kph': 3.6,
#       'wind_degree': 112,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 93,
#       'cloud': 43,
#       'feelslike_c': 11.0,
#       'feelslike_f': 51.8,
#       'windchill_c': 11.0,
#       'windchill_f': 51.8,
#       'heatindex_c': 10.7,
#       'heatindex_f': 51.3,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.4,
#       'gust_kph': 5.4,
#       'uv': 1.0},
#      {'time_epoch': 1674010800,
#       'time': '2023-01-17 22:00',
#       'temp_c': 10.6,
#       'temp_f': 51.1,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.0,
#       'wind_kph': 3.2,
#       'wind_degree': 121,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.6,
#       'precip_in': 0.02,
#       'humidity': 93,
#       'cloud': 80,
#       'feelslike_c': 11.1,
#       'feelslike_f': 52.0,
#       'windchill_c': 11.1,
#       'windchill_f': 52.0,
#       'heatindex_c': 10.6,
#       'heatindex_f': 51.1,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 48.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 81,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 1.0},
#      {'time_epoch': 1674014400,
#       'time': '2023-01-17 23:00',
#       'temp_c': 10.7,
#       'temp_f': 51.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 1.3,
#       'wind_kph': 2.2,
#       'wind_degree': 124,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 92,
#       'cloud': 41,
#       'feelslike_c': 10.7,
#       'feelslike_f': 51.3,
#       'windchill_c': 10.7,
#       'windchill_f': 51.3,
#       'heatindex_c': 10.7,
#       'heatindex_f': 51.3,
#       'dewpoint_c': 9.5,
#       'dewpoint_f': 49.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 2.0,
#       'gust_kph': 3.2,
#       'uv': 1.0}]}]}}

# %%
#Una buena practica cuando tenemos un Json es obtener las keys
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
#Entramos a la seccion forecast y obtenemos las llaves
response['forecast'].keys()
# Out:
# dict_keys(['forecastday'])

# %%
#Entramos a la seccion forecast y obtenemos las llaves
response['forecast']['forecastday'][0].keys()
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %%
#Len al campo hora para verificar que traiga 24 horas
len(response['forecast']['forecastday'][0]['hour'])
# Out:
# 24

# %%
#Extraeremos la hora requerida (para nosotros la 1 (puede cambiarse por cualquiera de las 24 horas))
response['forecast']['forecastday'][0]['hour'][1]
# Out:
# {'time_epoch': 1673935200,
#  'time': '2023-01-17 01:00',
#  'temp_c': 9.8,
#  'temp_f': 49.6,
#  'is_day': 0,
#  'condition': {'text': 'Partly cloudy',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#   'code': 1003},
#  'wind_mph': 1.8,
#  'wind_kph': 2.9,
#  'wind_degree': 139,
#  'wind_dir': 'SE',
#  'pressure_mb': 1017.0,
#  'pressure_in': 30.02,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 94,
#  'cloud': 56,
#  'feelslike_c': 9.8,
#  'feelslike_f': 49.6,
#  'windchill_c': 9.8,
#  'windchill_f': 49.6,
#  'heatindex_c': 9.8,
#  'heatindex_f': 49.6,
#  'dewpoint_c': 8.9,
#  'dewpoint_f': 48.0,
#  'will_it_rain': 0,
#  'chance_of_rain': 0,
#  'will_it_snow': 0,
#  'chance_of_snow': 0,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'gust_mph': 2.9,
#  'gust_kph': 4.7,
#  'uv': 1.0}

# %%
#Extraeremos la fecha y hora
response['forecast']['forecastday'][0]['hour'][1]['time']
# Out:
# '2023-01-17 01:00'

# %%
#Extraeremos la fecha (con el split)
response['forecast']['forecastday'][0]['hour'][1]['time'].split()[0]
# Out:
# '2023-01-17'

# %%
#Extraeremos la hora
int( response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1].split(':')[0]) # Hora
# Out:
# 1

# %%
#Condicion 
response['forecast']['forecastday'][0]['hour'][1]
# Out:
# {'time_epoch': 1673935200,
#  'time': '2023-01-17 01:00',
#  'temp_c': 9.8,
#  'temp_f': 49.6,
#  'is_day': 0,
#  'condition': {'text': 'Partly cloudy',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#   'code': 1003},
#  'wind_mph': 1.8,
#  'wind_kph': 2.9,
#  'wind_degree': 139,
#  'wind_dir': 'SE',
#  'pressure_mb': 1017.0,
#  'pressure_in': 30.02,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 94,
#  'cloud': 56,
#  'feelslike_c': 9.8,
#  'feelslike_f': 49.6,
#  'windchill_c': 9.8,
#  'windchill_f': 49.6,
#  'heatindex_c': 9.8,
#  'heatindex_f': 49.6,
#  'dewpoint_c': 8.9,
#  'dewpoint_f': 48.0,
#  'will_it_rain': 0,
#  'chance_of_rain': 0,
#  'will_it_snow': 0,
#  'chance_of_snow': 0,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'gust_mph': 2.9,
#  'gust_kph': 4.7,
#  'uv': 1.0}

# %%
#Condicion
response['forecast']['forecastday'][0]['hour'][1]['condition']['text']
# Out:
# 'Partly cloudy'

# %%
#Temperatura
response['forecast']['forecastday'][0]['hour'][1]['temp_c']
# Out:
# 9.8

# %%
#Llovera
response['forecast']['forecastday'][0]['hour'][1]['will_it_rain']
# Out:
# 0

# %%
#Chance de lluvia
response['forecast']['forecastday'][0]['hour'][1]['chance_of_rain']
# Out:
# 0

# %% [markdown]
# # DATAFRAME

# %%
#Función que retorna los valores necesarios del clima
def get_forecast(response, i):
    fecha = response['forecast']['forecastday'][0]['hour'][i]['time'].split()[0]
    hora = int( response['forecast']['forecastday'][0]['hour'][i]['time'].split()[1].split(':')[0])
    condicion = response['forecast']['forecastday'][0]['hour'][i]['condition']['text']
    temp = response['forecast']['forecastday'][0]['hour'][i]['temp_c']
    rain = response['forecast']['forecastday'][0]['hour'][i]['will_it_rain']
    prob_rain = response['forecast']['forecastday'][0]['hour'][i]['chance_of_rain']
    
    return fecha, hora, condicion, temp, rain, prob_rain

# %%
#Este array contendra el clima en sus respectivas horas
datos = []

#La libreria tqdm permite monitorear los ciclos con una barra de carga, en este caso verde
for i in tqdm(range(len(response['forecast']['forecastday'][0]['hour'])), colour = 'green'):
    datos.append(get_forecast(response, i))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<?, ?it/s]

# %%
datos[0] #Datos para la hora 0

# %%
#Construccion del dataframe

#Construccion de las columnas
col = ['Fecha', 'Hora', 'Condicion', 'Temperatura', 'Lluvia', 'Probabilidad_Lluvia']

#Le pasamos los datos al dataframe (el Array datos y las columnas)
df = pd.DataFrame(datos, columns = col)

#Impresion del dataframe
df
# Out:
#          Fecha  Hora             Condicion  Temperatura  Lluvia  \
# 0   2023-01-17     0  Patchy rain possible          9.9       0
# 1   2023-01-17     1         Partly cloudy          9.8       0
# 2   2023-01-17     2         Partly cloudy          9.4       0
# 3   2023-01-17     3         Partly cloudy          9.6       0
# 4   2023-01-17     4  Patchy rain possible          9.9       1
# 5   2023-01-17     5         Partly cloudy          9.9       0
# 6   2023-01-17     6         Partly cloudy          9.8       0
# 7   2023-01-17     7         Partly cloudy         10.4       0
# 8   2023-01-17     8         Partly cloudy         11.5       0
# 9   2023-01-17     9         Partly cloudy         12.9       0
# 10  2023-01-17    10  Patchy rain possible         14.4       0
# 11  2023-01-17    11                 Sunny         16.9       0
# 12  2023-01-17    12  Patchy rain possible         17.6       1
# 13  2023-01-17    13                 Sunny         17.3       0
# 14  2023-01-17    14  Patchy rain possible         15.7       0
# 15  2023-01-17    15         Partly cloudy         14.4       0
# 16  2023-01-17    16     Light rain shower         14.5       0
# 17  2023-01-17    17                Cloudy         14.1       0
# 18  2023-01-17    18  Patchy rain possible         12.5       0
# 19  2023-01-17    19         Partly cloudy         12.2       0
# 20  2023-01-17    20  Patchy rain possible         10.7       1
# 21  2023-01-17    21         Partly cloudy         10.7       0
# 22  2023-01-17    22  Patchy rain possible         10.6       1
# 23  2023-01-17    23         Partly cloudy         10.7       0
#
#     Probabilidad_Lluvia
# 0                    60
# 1                     0
# 2                     0
# 3                     0
# 4                    81
# 5                     0
# 6                     0
# 7                     0
# 8                     0
# 9                     0
# 10                   67
# 11                    0
# 12                   74
# 13                    0
# 14                   61
# 15                    0
# 16                   64
# 17                    0
# 18                   65
# 19                    0
# 20                   85
# 21                    0
# 22                   81
# 23                    0

# %%
#Filtraeremos el estado de lluvia y la hora (porque el usuario no le interesa la noche)
df_rain = df[(df['Lluvia']==1) & (df['Hora']>6) & (df['Hora']<22)]

# %%
#Seleccionaremos solo las columnas Hora y Condicion
df_rain = df_rain[['Hora', 'Condicion']]

# %%
df_rain
# Out:
#     Hora             Condicion
# 12    12  Patchy rain possible
# 20    20  Patchy rain possible

# %%
#Reemplazar para que la llave primaria sea la hora.
df_rain.set_index('Hora', inplace = True)

# %%
df_rain
# Out:
#                  Condicion
# Hora
# 12    Patchy rain possible
# 20    Patchy rain possible

# %% [markdown]
# # # MENSAJE -TEMPLATE

# %%
'\n¡Hola! \n \n \n El pronostico del clima para hoy'+df['Fecha'][0]+' en '+ query + 'es:'+ str(df_rain)
# Out:
# '\n¡Hola! \n \n \n El pronostico del clima para hoy2023-01-17 en Bogotáes:                 Condicion\nHora                      \n12    Patchy rain possible\n20    Patchy rain possible'

# %%
PHONE_NUMBER #Nuestro numero de celular
# Out:
# '+17432224721'

# %%
#Codigo extraido de twilio (template)
# Find your Account SID and Auth Token at twilio.com/console
# and set the environment variables. See http://twil.io/secure

account_sid = TWILIO_ACCOUNT_SID
auth_token = TWILIO_AUTH_TOKEN
client = Client(account_sid, auth_token)

'''
#Numeros a los que se les enviará el mensaje (solo para numeros verificados (pago))
numbers_to_message = ['+573228784083', '+57xxxxxx', '+57xxxxx', '+57xxxxx']
for number in numbers_to_message:
    client.messages.create(
        body='\n¡Hola! \n Este mensaje fue enviado por el mejor ingeniero de datos del mundo usando una API y AWS, ¡eres muy afortunado de recibirlo!. \n \n ¡Si sabes quien soy enviame un mensaje por whas! \n \n \n El pronostico de lluvia en hora es para el dia '+df['Fecha'][0]+' en '+ query + 'es:'+ str(df_rain),
        from_=PHONE_NUMBER,
        to=number
    )
    print(message.sid)
'''

#Mensaje a mi celular
client.messages.create(
    body='\n¡Hola! \n \n El pronostico de lluvia en hora es para el dia '+df['Fecha'][0]+' en '+ query + ' es: \n'+ str(df_rain),
    from_=PHONE_NUMBER,
    to='+573228784083'
)
print(message.sid)
# Out:
# SM2e09e714df06ff24e38ab551be3329f5
